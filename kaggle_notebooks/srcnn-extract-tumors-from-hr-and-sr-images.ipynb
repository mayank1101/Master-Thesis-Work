# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
## Load all the necessary packages

# %matplotlib inline

import matplotlib.pyplot as plt
import skimage.transform
from skimage import data, io, filters
import numpy as np
from numpy import array
from skimage.transform import rescale, resize
from skimage.transform import resize
import os
import PIL
import pandas as pd
import imageio


from matplotlib.pyplot import imread
import cv2
import h5py

# %%
## Load Directory Paths

def load_path(path):
    directories = []
    if os.path.isdir(path):
        print('directory path: ', path)
        directories.append(path)
    for elem in os.listdir(path): #check for nested dir within parent dir
        if os.path.isdir(os.path.join(path,elem)):
            print('inside nested dir')
            directories = directories + load_path(os.path.join(path,elem))
            directories.append(os.path.join(path,elem))
    print('directories: ', directories)
    return directories

# %%
## Load Images from directory

def load_data_from_dirs(dirs, ext):
    files = []
    file_names = []
    count = 0
    
    for d in dirs:
        for f in os.listdir(d):
            if f.endswith(ext):
                image = cv2.imread(os.path.join(d,f))
                files.append(image)
                file_names.append(os.path.join(d,f))
                count = count + 1
    
    print('list of files: ',len(files))
    print('list of files path: ', len(file_names), 'file path: ', file_names[0])
    print('Files Read: ',count)
    
    return files

# %%
def load_matdata_from_dirs(dirs, ext):
    files = []
    file_names = []
    count = 0
    
    for d in dirs:
        for f in os.listdir(d):
            if f.endswith(ext):
                image = h5py.File(os.path.join(d,f), 'r')
                files.append(image)
                file_names.append(os.path.join(d,f))
                count = count + 1
    
    print('list of files: ',len(files), 'file: ', files[0])
    print('list of files path: ', len(file_names), 'file path: ', file_names[0])
    print('Files Read: ',count)
    
    return files

# %%
## Load Images

def load_data(directory, ext):
    files = load_data_from_dirs(load_path(directory), ext)
    return files

# %%
## Load .mat data files

def load_matdata(directory, ext):
    files = load_matdata_from_dirs(load_path(directory), ext)
    return files

# %%
matfiles = load_matdata("../input/mydataset/BrainTumorData/", ".mat")
# Out:
# directory path:  ../input/mydataset/BrainTumorData/
# directories:  ['../input/mydataset/BrainTumorData/']
# list of files:  3064 file:  <HDF5 file "2912.mat" (mode r)>
# list of files path:  3064 file path:  ../input/mydataset/BrainTumorData/2912.mat
# Files Read:  3064

# %%
## get mask for the images

images_h5 = matfiles[:1000]
mask_arr = [img_h5['cjdata']['tumorMask'][()].astype(np.uint32) for img_h5 in images_h5]

# %%
## remove mask not of dimensions 512x512

fil_mask_arr = []
for mask in mask_arr:
    if mask.shape == (512,512):
        fil_mask_arr.append(mask)

# %%
## get mask for sr images

img_mask = []
for i in range(600,800):
    img_mask.append(fil_mask_arr[i])

# %%
## Load Images from directory

def load_data_from_dirs(dirs, ext):
    files = []
    file_names = []
    count = 0
    res = {}
    
    for d in dirs:
        for f in os.listdir(d):
            if f.endswith(ext):
                image = cv2.imread(os.path.join(d,f))
                files.append(image)
                file_names.append(os.path.join(d,f))
                count = count + 1
                res[int(os.path.join(d,f)[36:-4])] = image
    
    print('list of files: ',len(files))
    print('list of files path: ', len(file_names), 'file path: ', file_names[0])
    print('Files Read: ',count)
    
    return res

# %%
## Load SR Images from directory
print(len('../input/srcnn-results/SR_imgs/'))
sr_imgs = load_data("../input/srcnn-results/SR_imgs/", ".png")
# Out:
# 31
# directory path:  ../input/srcnn-results/SR_imgs/
# directories:  ['../input/srcnn-results/SR_imgs/']
# list of files:  200
# list of files path:  200 file path:  ../input/srcnn-results/SR_imgs/newHR49.png
# Files Read:  200

# %%
from collections import OrderedDict
# sorted(test_list, key = int)
srt_sr_imgs = OrderedDict(sorted(sr_imgs.items()))

# %%
## Normalize pixel values between 0 - 255

sr_images = []
for i in range(1, len(srt_sr_imgs)):
    img = cv2.normalize(np.float32(srt_sr_imgs[i]), None, alpha = 0, beta = 255, norm_type = cv2.NORM_MINMAX, dtype = cv2.CV_32F)
    sr_images.append(cv2.cvtColor(img, cv2.COLOR_BGR2GRAY).astype(np.uint32))

# %%
## Get Tumors from SR Images
sr_tumor_arr = []
sr_tumor_arr = array([img * mask for img, mask in zip(sr_images, img_mask)], dtype=object)

# %%
len(sr_tumor_arr)
# Out:
# 199

# %%
## Load Images from directory

def load_data_from_dirs(dirs, ext):
    files = []
    file_names = []
    count = 0
    res = {}
    
    for d in dirs:
        for f in os.listdir(d):
            if f.endswith(ext):
                image = cv2.imread(os.path.join(d,f))
                files.append(image)
                file_names.append(os.path.join(d,f))
                count = count + 1
                res[int(os.path.join(d,f)[33:-4])] = image
    
    print('list of files: ',len(files))
    print('list of files path: ', len(file_names), 'file path: ', file_names[0])
    print('Files Read: ',count)
    
    return res

# %%
## Load HR Images from directory
print(len('../input/srcnn-results/HR_imgs/'))
hr_imgs = load_data("../input/srcnn-results/HR_imgs/", ".png")
# Out:
# 31
# directory path:  ../input/srcnn-results/HR_imgs/
# directories:  ['../input/srcnn-results/HR_imgs/']
# list of files:  200
# list of files path:  200 file path:  ../input/srcnn-results/HR_imgs/HR189.png
# Files Read:  200

# %%
from collections import OrderedDict
# sorted(test_list, key = int)
srt_hr_imgs = OrderedDict(sorted(hr_imgs.items()))

# %%
## Normalize pixel values between 0 - 255

hr_images = []
for i in range(1,len(srt_hr_imgs)):
    img = cv2.normalize(np.float32(srt_hr_imgs[i]), None, alpha = 0, beta = 255, norm_type = cv2.NORM_MINMAX, dtype = cv2.CV_32F)
    hr_images.append(cv2.cvtColor(img, cv2.COLOR_BGR2GRAY).astype(np.uint32))

# %%
## Get Tumors from HR Images
hr_tumor_arr = []
hr_tumor_arr = array([img * mask for img, mask in zip(hr_images, img_mask)], dtype=object)

# %%
len(hr_tumor_arr)
# Out:
# 199

# %%
def displayImages(img_arr):    
    width=8
    height=8
    rows = 3
    cols = 4
    axes=[]

    fig=plt.figure(figsize=(10,10))

    for i in range(rows * cols):
        axes.append( fig.add_subplot(rows, cols, i+1) )
        subplot_title=("Image: "+str(i+1))
        axes[-1].set_title(subplot_title)  
        plt.imshow(np.asarray(img_arr[i], dtype=float).squeeze(), cmap='gray')
        plt.axis('off')
    fig.tight_layout()    
    plt.show()

# %%
def displayUMatImages(img_arr):    
    width=8
    height=8
    rows = 3
    cols = 4
    axes=[]

    fig=plt.figure(figsize=(10,10))

    for i in range(rows * cols):
        axes.append( fig.add_subplot(rows, cols, i+1) )
        subplot_title=("Image: "+str(i+1))
        axes[-1].set_title(subplot_title)  
        plt.imshow(img_arr[i].get().astype('f'))
        plt.axis('off')
    fig.tight_layout()    
    plt.show()

# %%
## Display SR Image Tumors

displayImages(sr_tumor_arr)

# %%
## Display SR Image Tumors

displayImages(hr_tumor_arr)

# %%
os.mkdir('./sr_tumor_imgs')
os.mkdir('./hr_tumor_imgs')

# %%
for idx in range(199):
    imageio.imwrite('./sr_tumor_imgs/SRTMR_'+str(idx+1)+'.png', np.asarray(sr_tumor_arr[idx], dtype=float))
    imageio.imwrite('./hr_tumor_imgs/HRTMR_'+str(idx+1)+'.png', np.asarray(hr_tumor_arr[idx], dtype=float))

# %%
# %%!
#
# zip -r sr_tumor.zip ./sr_tumor_imgs
# Out:
# ['  adding: sr_tumor_imgs/ (stored 0%)',
#  '  adding: sr_tumor_imgs/SRTMR_148.png (deflated 16%)',
#  '  adding: sr_tumor_imgs/SRTMR_142.png (deflated 8%)',
#  '  adding: sr_tumor_imgs/SRTMR_122.png (deflated 14%)',
#  '  adding: sr_tumor_imgs/SRTMR_73.png (deflated 10%)',
#  '  adding: sr_tumor_imgs/SRTMR_46.png (deflated 6%)',
#  '  adding: sr_tumor_imgs/SRTMR_174.png (deflated 9%)',
#  '  adding: sr_tumor_imgs/SRTMR_42.png (deflated 7%)',
#  '  adding: sr_tumor_imgs/SRTMR_172.png (deflated 18%)',
#  '  adding: sr_tumor_imgs/SRTMR_136.png (deflated 14%)',
#  '  adding: sr_tumor_imgs/SRTMR_130.png (deflated 7%)',
#  '  adding: sr_tumor_imgs/SRTMR_53.png (deflated 9%)',
#  '  adding: sr_tumor_imgs/SRTMR_17.png (deflated 12%)',
#  '  adding: sr_tumor_imgs/SRTMR_32.png (deflated 12%)',
#  '  adding: sr_tumor_imgs/SRTMR_69.png (deflated 6%)',
#  '  adding: sr_tumor_imgs/SRTMR_7.png (deflated 21%)',
#  '  adding: sr_tumor_imgs/SRTMR_75.png (deflated 17%)',
#  '  adding: sr_tumor_imgs/SRTMR_109.png (deflated 12%)',
#  '  adding: sr_tumor_imgs/SRTMR_111.png (deflated 23%)',
#  '  adding: sr_tumor_imgs/SRTMR_178.png (deflated 16%)',
#  '  adding: sr_tumor_imgs/SRTMR_55.png (deflated 8%)',
#  '  adding: sr_tumor_imgs/SRTMR_51.png (deflated 5%)',
#  '  adding: sr_tumor_imgs/SRTMR_151.png (deflated 10%)',
#  '  adding: sr_tumor_imgs/SRTMR_82.png (deflated 15%)',
#  '  adding: sr_tumor_imgs/SRTMR_117.png (deflated 11%)',
#  '  adding: sr_tumor_imgs/SRTMR_36.png (deflated 12%)',
#  '  adding: sr_tumor_imgs/SRTMR_161.png (deflated 17%)',
#  '  adding: sr_tumor_imgs/SRTMR_62.png (deflated 5%)',
#  '  adding: sr_tumor_imgs/SRTMR_88.png (deflated 7%)',
#  '  adding: sr_tumor_imgs/SRTMR_137.png (deflated 14%)',
#  '  adding: sr_tumor_imgs/SRTMR_65.png (deflated 6%)',
#  '  adding: sr_tumor_imgs/SRTMR_44.png (deflated 17%)',
#  '  adding: sr_tumor_imgs/SRTMR_107.png (deflated 11%)',
#  '  adding: sr_tumor_imgs/SRTMR_83.png (deflated 11%)',
#  '  adding: sr_tumor_imgs/SRTMR_10.png (deflated 7%)',
#  '  adding: sr_tumor_imgs/SRTMR_160.png (deflated 10%)',
#  '  adding: sr_tumor_imgs/SRTMR_156.png (deflated 36%)',
#  '  adding: sr_tumor_imgs/SRTMR_27.png (deflated 7%)',
#  '  adding: sr_tumor_imgs/SRTMR_35.png (deflated 12%)',
#  '  adding: sr_tumor_imgs/SRTMR_145.png (deflated 6%)',
#  '  adding: sr_tumor_imgs/SRTMR_188.png (deflated 9%)',
#  '  adding: sr_tumor_imgs/SRTMR_61.png (deflated 12%)',
#  '  adding: sr_tumor_imgs/SRTMR_177.png (deflated 8%)',
#  '  adding: sr_tumor_imgs/SRTMR_167.png (deflated 7%)',
#  '  adding: sr_tumor_imgs/SRTMR_12.png (deflated 8%)',
#  '  adding: sr_tumor_imgs/SRTMR_85.png (deflated 8%)',
#  '  adding: sr_tumor_imgs/SRTMR_5.png (deflated 7%)',
#  '  adding: sr_tumor_imgs/SRTMR_54.png (deflated 16%)',
#  '  adding: sr_tumor_imgs/SRTMR_50.png (deflated 28%)',
#  '  adding: sr_tumor_imgs/SRTMR_192.png (deflated 7%)',
#  '  adding: sr_tumor_imgs/SRTMR_110.png (deflated 12%)',
#  '  adding: sr_tumor_imgs/SRTMR_21.png (deflated 9%)',
#  '  adding: sr_tumor_imgs/SRTMR_76.png (deflated 16%)',
#  '  adding: sr_tumor_imgs/SRTMR_70.png (deflated 10%)',
#  '  adding: sr_tumor_imgs/SRTMR_23.png (deflated 11%)',
#  '  adding: sr_tumor_imgs/SRTMR_72.png (deflated 17%)',
#  '  adding: sr_tumor_imgs/SRTMR_115.png (deflated 8%)',
#  '  adding: sr_tumor_imgs/SRTMR_112.png (deflated 17%)',
#  '  adding: sr_tumor_imgs/SRTMR_191.png (deflated 12%)',
#  '  adding: sr_tumor_imgs/SRTMR_144.png (deflated 14%)',
#  '  adding: sr_tumor_imgs/SRTMR_152.png (deflated 32%)',
#  '  adding: sr_tumor_imgs/SRTMR_2.png (deflated 14%)',
#  '  adding: sr_tumor_imgs/SRTMR_155.png (deflated 11%)',
#  '  adding: sr_tumor_imgs/SRTMR_57.png (deflated 13%)',
#  '  adding: sr_tumor_imgs/SRTMR_11.png (deflated 9%)',
#  '  adding: sr_tumor_imgs/SRTMR_49.png (deflated 7%)',
#  '  adding: sr_tumor_imgs/SRTMR_138.png (deflated 10%)',
#  '  adding: sr_tumor_imgs/SRTMR_159.png (deflated 13%)',
#  '  adding: sr_tumor_imgs/SRTMR_181.png (deflated 8%)',
#  '  adding: sr_tumor_imgs/SRTMR_58.png (deflated 12%)',
#  '  adding: sr_tumor_imgs/SRTMR_48.png (deflated 20%)',
#  '  adding: sr_tumor_imgs/SRTMR_63.png (deflated 31%)',
#  '  adding: sr_tumor_imgs/SRTMR_171.png (deflated 33%)',
#  '  adding: sr_tumor_imgs/SRTMR_187.png (deflated 13%)',
#  '  adding: sr_tumor_imgs/SRTMR_103.png (deflated 31%)',
#  '  adding: sr_tumor_imgs/SRTMR_106.png (deflated 10%)',
#  '  adding: sr_tumor_imgs/SRTMR_197.png (deflated 30%)',
#  '  adding: sr_tumor_imgs/SRTMR_139.png (deflated 24%)',
#  '  adding: sr_tumor_imgs/SRTMR_149.png (deflated 7%)',
#  '  adding: sr_tumor_imgs/SRTMR_30.png (deflated 5%)',
#  '  adding: sr_tumor_imgs/SRTMR_168.png (deflated 11%)',
#  '  adding: sr_tumor_imgs/SRTMR_182.png (deflated 13%)',
#  '  adding: sr_tumor_imgs/SRTMR_99.png (deflated 8%)',
#  '  adding: sr_tumor_imgs/SRTMR_78.png (deflated 9%)',
#  '  adding: sr_tumor_imgs/SRTMR_120.png (deflated 9%)',
#  '  adding: sr_tumor_imgs/SRTMR_77.png (deflated 11%)',
#  '  adding: sr_tumor_imgs/SRTMR_127.png (deflated 9%)',
#  '  adding: sr_tumor_imgs/SRTMR_92.png (deflated 11%)',
#  '  adding: sr_tumor_imgs/SRTMR_141.png (deflated 9%)',
#  '  adding: sr_tumor_imgs/SRTMR_114.png (deflated 5%)',
#  '  adding: sr_tumor_imgs/SRTMR_119.png (deflated 8%)',
#  '  adding: sr_tumor_imgs/SRTMR_24.png (deflated 12%)',
#  '  adding: sr_tumor_imgs/SRTMR_60.png (deflated 11%)',
#  '  adding: sr_tumor_imgs/SRTMR_98.png (deflated 13%)',
#  '  adding: sr_tumor_imgs/SRTMR_116.png (deflated 6%)',
#  '  adding: sr_tumor_imgs/SRTMR_173.png (deflated 13%)',
#  '  adding: sr_tumor_imgs/SRTMR_96.png (deflated 11%)',
#  '  adding: sr_tumor_imgs/SRTMR_19.png (deflated 7%)',
#  '  adding: sr_tumor_imgs/SRTMR_135.png (deflated 13%)',
#  '  adding: sr_tumor_imgs/SRTMR_22.png (deflated 7%)',
#  '  adding: sr_tumor_imgs/SRTMR_56.png (deflated 8%)',
#  '  adding: sr_tumor_imgs/SRTMR_150.png (deflated 15%)',
#  '  adding: sr_tumor_imgs/SRTMR_89.png (deflated 9%)',
#  '  adding: sr_tumor_imgs/SRTMR_186.png (deflated 18%)',
#  '  adding: sr_tumor_imgs/SRTMR_18.png (deflated 23%)',
#  '  adding: sr_tumor_imgs/SRTMR_169.png (deflated 25%)',
#  '  adding: sr_tumor_imgs/SRTMR_13.png (deflated 10%)',
#  '  adding: sr_tumor_imgs/SRTMR_94.png (deflated 40%)',
#  '  adding: sr_tumor_imgs/SRTMR_33.png (deflated 7%)',
#  '  adding: sr_tumor_imgs/SRTMR_6.png (deflated 7%)',
#  '  adding: sr_tumor_imgs/SRTMR_190.png (deflated 15%)',
#  '  adding: sr_tumor_imgs/SRTMR_38.png (deflated 5%)',
#  '  adding: sr_tumor_imgs/SRTMR_134.png (deflated 18%)',
#  '  adding: sr_tumor_imgs/SRTMR_67.png (deflated 18%)',
#  '  adding: sr_tumor_imgs/SRTMR_52.png (deflated 13%)',
#  '  adding: sr_tumor_imgs/SRTMR_166.png (deflated 6%)',
#  '  adding: sr_tumor_imgs/SRTMR_132.png (deflated 8%)',
#  '  adding: sr_tumor_imgs/SRTMR_31.png (deflated 10%)',
#  '  adding: sr_tumor_imgs/SRTMR_47.png (deflated 9%)',
#  '  adding: sr_tumor_imgs/SRTMR_9.png (deflated 11%)',
#  '  adding: sr_tumor_imgs/SRTMR_158.png (deflated 22%)',
#  '  adding: sr_tumor_imgs/SRTMR_196.png (deflated 9%)',
#  '  adding: sr_tumor_imgs/SRTMR_128.png (deflated 8%)',
#  '  adding: sr_tumor_imgs/SRTMR_108.png (deflated 7%)',
#  '  adding: sr_tumor_imgs/SRTMR_126.png (deflated 7%)',
#  '  adding: sr_tumor_imgs/SRTMR_37.png (deflated 5%)',
#  '  adding: sr_tumor_imgs/SRTMR_40.png (deflated 14%)',
#  '  adding: sr_tumor_imgs/SRTMR_143.png (deflated 22%)',
#  '  adding: sr_tumor_imgs/SRTMR_80.png (deflated 11%)',
#  '  adding: sr_tumor_imgs/SRTMR_93.png (deflated 8%)',
#  '  adding: sr_tumor_imgs/SRTMR_84.png (deflated 18%)',
#  '  adding: sr_tumor_imgs/SRTMR_193.png (deflated 11%)',
#  '  adding: sr_tumor_imgs/SRTMR_129.png (deflated 28%)',
#  '  adding: sr_tumor_imgs/SRTMR_43.png (deflated 16%)',
#  '  adding: sr_tumor_imgs/SRTMR_165.png (deflated 16%)',
#  '  adding: sr_tumor_imgs/SRTMR_16.png (deflated 44%)',
#  '  adding: sr_tumor_imgs/SRTMR_162.png (deflated 8%)',
#  '  adding: sr_tumor_imgs/SRTMR_153.png (deflated 10%)',
#  '  adding: sr_tumor_imgs/SRTMR_71.png (deflated 10%)',
#  '  adding: sr_tumor_imgs/SRTMR_14.png (deflated 23%)',
#  '  adding: sr_tumor_imgs/SRTMR_29.png (deflated 19%)',
#  '  adding: sr_tumor_imgs/SRTMR_1.png (deflated 13%)',
#  '  adding: sr_tumor_imgs/SRTMR_34.png (deflated 12%)',
#  '  adding: sr_tumor_imgs/SRTMR_194.png (deflated 29%)',
#  '  adding: sr_tumor_imgs/SRTMR_59.png (deflated 17%)',
#  '  adding: sr_tumor_imgs/SRTMR_105.png (deflated 41%)',
#  '  adding: sr_tumor_imgs/SRTMR_118.png (deflated 6%)',
#  '  adding: sr_tumor_imgs/SRTMR_147.png (deflated 18%)',
#  '  adding: sr_tumor_imgs/SRTMR_45.png (deflated 33%)',
#  '  adding: sr_tumor_imgs/SRTMR_28.png (deflated 7%)',
#  '  adding: sr_tumor_imgs/SRTMR_39.png (deflated 11%)',
#  '  adding: sr_tumor_imgs/SRTMR_154.png (deflated 7%)',
#  '  adding: sr_tumor_imgs/SRTMR_90.png (deflated 7%)',
#  '  adding: sr_tumor_imgs/SRTMR_175.png (deflated 12%)',
#  '  adding: sr_tumor_imgs/SRTMR_183.png (deflated 41%)',
#  '  adding: sr_tumor_imgs/SRTMR_79.png (deflated 13%)',
#  '  adding: sr_tumor_imgs/SRTMR_8.png (deflated 21%)',
#  '  adding: sr_tumor_imgs/SRTMR_20.png (deflated 9%)',
#  '  adding: sr_tumor_imgs/SRTMR_195.png (deflated 9%)',
#  '  adding: sr_tumor_imgs/SRTMR_86.png (deflated 39%)',
#  '  adding: sr_tumor_imgs/SRTMR_133.png (deflated 8%)',
#  '  adding: sr_tumor_imgs/SRTMR_101.png (deflated 8%)',
#  '  adding: sr_tumor_imgs/SRTMR_121.png (deflated 18%)',
#  '  adding: sr_tumor_imgs/SRTMR_74.png (deflated 5%)',
#  '  adding: sr_tumor_imgs/SRTMR_179.png (deflated 11%)',
#  '  adding: sr_tumor_imgs/SRTMR_123.png (deflated 12%)',
#  '  adding: sr_tumor_imgs/SRTMR_198.png (deflated 25%)',
#  '  adding: sr_tumor_imgs/SRTMR_3.png (deflated 7%)',
#  '  adding: sr_tumor_imgs/SRTMR_189.png (deflated 7%)',
#  '  adding: sr_tumor_imgs/SRTMR_15.png (deflated 6%)',
#  '  adding: sr_tumor_imgs/SRTMR_124.png (deflated 24%)',
#  '  adding: sr_tumor_imgs/SRTMR_41.png (deflated 8%)',
#  '  adding: sr_tumor_imgs/SRTMR_164.png (deflated 9%)',
#  '  adding: sr_tumor_imgs/SRTMR_25.png (deflated 9%)',
#  '  adding: sr_tumor_imgs/SRTMR_113.png (deflated 35%)',
#  '  adding: sr_tumor_imgs/SRTMR_185.png (deflated 16%)',
#  '  adding: sr_tumor_imgs/SRTMR_97.png (deflated 11%)',
#  '  adding: sr_tumor_imgs/SRTMR_68.png (deflated 12%)',
#  '  adding: sr_tumor_imgs/SRTMR_64.png (deflated 29%)',
#  '  adding: sr_tumor_imgs/SRTMR_180.png (deflated 9%)',
#  '  adding: sr_tumor_imgs/SRTMR_170.png (deflated 6%)',
#  '  adding: sr_tumor_imgs/SRTMR_100.png (deflated 6%)',
#  '  adding: sr_tumor_imgs/SRTMR_4.png (deflated 18%)',
#  '  adding: sr_tumor_imgs/SRTMR_95.png (deflated 10%)',
#  '  adding: sr_tumor_imgs/SRTMR_91.png (deflated 14%)',
#  '  adding: sr_tumor_imgs/SRTMR_87.png (deflated 11%)',
#  '  adding: sr_tumor_imgs/SRTMR_26.png (deflated 6%)',
#  '  adding: sr_tumor_imgs/SRTMR_199.png (deflated 14%)',
#  '  adding: sr_tumor_imgs/SRTMR_140.png (deflated 40%)',
#  '  adding: sr_tumor_imgs/SRTMR_104.png (deflated 6%)',
#  '  adding: sr_tumor_imgs/SRTMR_125.png (deflated 11%)',
#  '  adding: sr_tumor_imgs/SRTMR_102.png (deflated 9%)',
#  '  adding: sr_tumor_imgs/SRTMR_146.png (deflated 10%)',
#  '  adding: sr_tumor_imgs/SRTMR_131.png (deflated 22%)',
#  '  adding: sr_tumor_imgs/SRTMR_184.png (deflated 5%)',
#  '  adding: sr_tumor_imgs/SRTMR_163.png (deflated 10%)',
#  '  adding: sr_tumor_imgs/SRTMR_66.png (deflated 11%)',
#  '  adding: sr_tumor_imgs/SRTMR_81.png (deflated 7%)',
#  '  adding: sr_tumor_imgs/SRTMR_176.png (deflated 13%)',
#  '  adding: sr_tumor_imgs/SRTMR_157.png (deflated 48%)']

# %%
# %%!
#
# zip -r hr_tumor.zip ./hr_tumor_imgs
# Out:
# ['  adding: hr_tumor_imgs/ (stored 0%)',
#  '  adding: hr_tumor_imgs/HRTMR_180.png (deflated 10%)',
#  '  adding: hr_tumor_imgs/HRTMR_76.png (deflated 11%)',
#  '  adding: hr_tumor_imgs/HRTMR_2.png (deflated 14%)',
#  '  adding: hr_tumor_imgs/HRTMR_97.png (deflated 8%)',
#  '  adding: hr_tumor_imgs/HRTMR_118.png (deflated 6%)',
#  '  adding: hr_tumor_imgs/HRTMR_185.png (deflated 13%)',
#  '  adding: hr_tumor_imgs/HRTMR_16.png (deflated 34%)',
#  '  adding: hr_tumor_imgs/HRTMR_124.png (deflated 17%)',
#  '  adding: hr_tumor_imgs/HRTMR_78.png (deflated 8%)',
#  '  adding: hr_tumor_imgs/HRTMR_15.png (deflated 5%)',
#  '  adding: hr_tumor_imgs/HRTMR_39.png (deflated 12%)',
#  '  adding: hr_tumor_imgs/HRTMR_163.png (deflated 11%)',
#  '  adding: hr_tumor_imgs/HRTMR_55.png (deflated 8%)',
#  '  adding: hr_tumor_imgs/HRTMR_34.png (deflated 14%)',
#  '  adding: hr_tumor_imgs/HRTMR_51.png (deflated 5%)',
#  '  adding: hr_tumor_imgs/HRTMR_132.png (deflated 9%)',
#  '  adding: hr_tumor_imgs/HRTMR_188.png (deflated 8%)',
#  '  adding: hr_tumor_imgs/HRTMR_77.png (deflated 11%)',
#  '  adding: hr_tumor_imgs/HRTMR_148.png (deflated 15%)',
#  '  adding: hr_tumor_imgs/HRTMR_12.png (deflated 5%)',
#  '  adding: hr_tumor_imgs/HRTMR_9.png (deflated 12%)',
#  '  adding: hr_tumor_imgs/HRTMR_47.png (deflated 8%)',
#  '  adding: hr_tumor_imgs/HRTMR_171.png (deflated 26%)',
#  '  adding: hr_tumor_imgs/HRTMR_134.png (deflated 12%)',
#  '  adding: hr_tumor_imgs/HRTMR_161.png (deflated 14%)',
#  '  adding: hr_tumor_imgs/HRTMR_141.png (deflated 9%)',
#  '  adding: hr_tumor_imgs/HRTMR_165.png (deflated 12%)',
#  '  adding: hr_tumor_imgs/HRTMR_111.png (deflated 16%)',
#  '  adding: hr_tumor_imgs/HRTMR_114.png (deflated 6%)',
#  '  adding: hr_tumor_imgs/HRTMR_149.png (deflated 9%)',
#  '  adding: hr_tumor_imgs/HRTMR_122.png (deflated 13%)',
#  '  adding: hr_tumor_imgs/HRTMR_20.png (deflated 10%)',
#  '  adding: hr_tumor_imgs/HRTMR_74.png (deflated 5%)',
#  '  adding: hr_tumor_imgs/HRTMR_33.png (deflated 6%)',
#  '  adding: hr_tumor_imgs/HRTMR_136.png (deflated 15%)',
#  '  adding: hr_tumor_imgs/HRTMR_45.png (deflated 16%)',
#  '  adding: hr_tumor_imgs/HRTMR_131.png (deflated 14%)',
#  '  adding: hr_tumor_imgs/HRTMR_83.png (deflated 10%)',
#  '  adding: hr_tumor_imgs/HRTMR_135.png (deflated 15%)',
#  '  adding: hr_tumor_imgs/HRTMR_189.png (deflated 9%)',
#  '  adding: hr_tumor_imgs/HRTMR_142.png (deflated 9%)',
#  '  adding: hr_tumor_imgs/HRTMR_44.png (deflated 12%)',
#  '  adding: hr_tumor_imgs/HRTMR_88.png (deflated 5%)',
#  '  adding: hr_tumor_imgs/HRTMR_48.png (deflated 11%)',
#  '  adding: hr_tumor_imgs/HRTMR_177.png (deflated 9%)',
#  '  adding: hr_tumor_imgs/HRTMR_6.png (deflated 8%)',
#  '  adding: hr_tumor_imgs/HRTMR_91.png (deflated 13%)',
#  '  adding: hr_tumor_imgs/HRTMR_128.png (deflated 10%)',
#  '  adding: hr_tumor_imgs/HRTMR_181.png (deflated 9%)',
#  '  adding: hr_tumor_imgs/HRTMR_116.png (deflated 6%)',
#  '  adding: hr_tumor_imgs/HRTMR_174.png (deflated 10%)',
#  '  adding: hr_tumor_imgs/HRTMR_86.png (deflated 27%)',
#  '  adding: hr_tumor_imgs/HRTMR_85.png (deflated 10%)',
#  '  adding: hr_tumor_imgs/HRTMR_150.png (deflated 12%)',
#  '  adding: hr_tumor_imgs/HRTMR_69.png (deflated 4%)',
#  '  adding: hr_tumor_imgs/HRTMR_147.png (deflated 13%)',
#  '  adding: hr_tumor_imgs/HRTMR_50.png (deflated 15%)',
#  '  adding: hr_tumor_imgs/HRTMR_156.png (deflated 22%)',
#  '  adding: hr_tumor_imgs/HRTMR_153.png (deflated 9%)',
#  '  adding: hr_tumor_imgs/HRTMR_22.png (deflated 5%)',
#  '  adding: hr_tumor_imgs/HRTMR_195.png (deflated 7%)',
#  '  adding: hr_tumor_imgs/HRTMR_144.png (deflated 12%)',
#  '  adding: hr_tumor_imgs/HRTMR_1.png (deflated 14%)',
#  '  adding: hr_tumor_imgs/HRTMR_70.png (deflated 9%)',
#  '  adding: hr_tumor_imgs/HRTMR_5.png (deflated 7%)',
#  '  adding: hr_tumor_imgs/HRTMR_37.png (deflated 5%)',
#  '  adding: hr_tumor_imgs/HRTMR_168.png (deflated 11%)',
#  '  adding: hr_tumor_imgs/HRTMR_80.png (deflated 10%)',
#  '  adding: hr_tumor_imgs/HRTMR_10.png (deflated 6%)',
#  '  adding: hr_tumor_imgs/HRTMR_129.png (deflated 17%)',
#  '  adding: hr_tumor_imgs/HRTMR_126.png (deflated 6%)',
#  '  adding: hr_tumor_imgs/HRTMR_3.png (deflated 9%)',
#  '  adding: hr_tumor_imgs/HRTMR_112.png (deflated 13%)',
#  '  adding: hr_tumor_imgs/HRTMR_49.png (deflated 6%)',
#  '  adding: hr_tumor_imgs/HRTMR_71.png (deflated 9%)',
#  '  adding: hr_tumor_imgs/HRTMR_152.png (deflated 20%)',
#  '  adding: hr_tumor_imgs/HRTMR_42.png (deflated 8%)',
#  '  adding: hr_tumor_imgs/HRTMR_31.png (deflated 9%)',
#  '  adding: hr_tumor_imgs/HRTMR_93.png (deflated 7%)',
#  '  adding: hr_tumor_imgs/HRTMR_60.png (deflated 10%)',
#  '  adding: hr_tumor_imgs/HRTMR_191.png (deflated 12%)',
#  '  adding: hr_tumor_imgs/HRTMR_198.png (deflated 17%)',
#  '  adding: hr_tumor_imgs/HRTMR_64.png (deflated 18%)',
#  '  adding: hr_tumor_imgs/HRTMR_157.png (deflated 36%)',
#  '  adding: hr_tumor_imgs/HRTMR_123.png (deflated 9%)',
#  '  adding: hr_tumor_imgs/HRTMR_160.png (deflated 12%)',
#  '  adding: hr_tumor_imgs/HRTMR_194.png (deflated 20%)',
#  '  adding: hr_tumor_imgs/HRTMR_24.png (deflated 11%)',
#  '  adding: hr_tumor_imgs/HRTMR_35.png (deflated 12%)',
#  '  adding: hr_tumor_imgs/HRTMR_176.png (deflated 14%)',
#  '  adding: hr_tumor_imgs/HRTMR_100.png (deflated 8%)',
#  '  adding: hr_tumor_imgs/HRTMR_199.png (deflated 12%)',
#  '  adding: hr_tumor_imgs/HRTMR_81.png (deflated 7%)',
#  '  adding: hr_tumor_imgs/HRTMR_164.png (deflated 10%)',
#  '  adding: hr_tumor_imgs/HRTMR_105.png (deflated 28%)',
#  '  adding: hr_tumor_imgs/HRTMR_154.png (deflated 6%)',
#  '  adding: hr_tumor_imgs/HRTMR_173.png (deflated 13%)',
#  '  adding: hr_tumor_imgs/HRTMR_145.png (deflated 6%)',
#  '  adding: hr_tumor_imgs/HRTMR_41.png (deflated 9%)',
#  '  adding: hr_tumor_imgs/HRTMR_115.png (deflated 10%)',
#  '  adding: hr_tumor_imgs/HRTMR_102.png (deflated 9%)',
#  '  adding: hr_tumor_imgs/HRTMR_120.png (deflated 8%)',
#  '  adding: hr_tumor_imgs/HRTMR_4.png (deflated 11%)',
#  '  adding: hr_tumor_imgs/HRTMR_193.png (deflated 11%)',
#  '  adding: hr_tumor_imgs/HRTMR_25.png (deflated 9%)',
#  '  adding: hr_tumor_imgs/HRTMR_169.png (deflated 17%)',
#  '  adding: hr_tumor_imgs/HRTMR_62.png (deflated 4%)',
#  '  adding: hr_tumor_imgs/HRTMR_155.png (deflated 9%)',
#  '  adding: hr_tumor_imgs/HRTMR_139.png (deflated 15%)',
#  '  adding: hr_tumor_imgs/HRTMR_58.png (deflated 9%)',
#  '  adding: hr_tumor_imgs/HRTMR_186.png (deflated 13%)',
#  '  adding: hr_tumor_imgs/HRTMR_107.png (deflated 12%)',
#  '  adding: hr_tumor_imgs/HRTMR_54.png (deflated 16%)',
#  '  adding: hr_tumor_imgs/HRTMR_57.png (deflated 14%)',
#  '  adding: hr_tumor_imgs/HRTMR_82.png (deflated 15%)',
#  '  adding: hr_tumor_imgs/HRTMR_43.png (deflated 12%)',
#  '  adding: hr_tumor_imgs/HRTMR_133.png (deflated 8%)',
#  '  adding: hr_tumor_imgs/HRTMR_87.png (deflated 7%)',
#  '  adding: hr_tumor_imgs/HRTMR_66.png (deflated 12%)',
#  '  adding: hr_tumor_imgs/HRTMR_179.png (deflated 12%)',
#  '  adding: hr_tumor_imgs/HRTMR_117.png (deflated 12%)',
#  '  adding: hr_tumor_imgs/HRTMR_56.png (deflated 7%)',
#  '  adding: hr_tumor_imgs/HRTMR_40.png (deflated 10%)',
#  '  adding: hr_tumor_imgs/HRTMR_143.png (deflated 17%)',
#  '  adding: hr_tumor_imgs/HRTMR_59.png (deflated 12%)',
#  '  adding: hr_tumor_imgs/HRTMR_46.png (deflated 6%)',
#  '  adding: hr_tumor_imgs/HRTMR_29.png (deflated 13%)',
#  '  adding: hr_tumor_imgs/HRTMR_172.png (deflated 13%)',
#  '  adding: hr_tumor_imgs/HRTMR_68.png (deflated 8%)',
#  '  adding: hr_tumor_imgs/HRTMR_79.png (deflated 12%)',
#  '  adding: hr_tumor_imgs/HRTMR_106.png (deflated 10%)',
#  '  adding: hr_tumor_imgs/HRTMR_96.png (deflated 11%)',
#  '  adding: hr_tumor_imgs/HRTMR_65.png (deflated 8%)',
#  '  adding: hr_tumor_imgs/HRTMR_38.png (deflated 6%)',
#  '  adding: hr_tumor_imgs/HRTMR_52.png (deflated 12%)',
#  '  adding: hr_tumor_imgs/HRTMR_103.png (deflated 18%)',
#  '  adding: hr_tumor_imgs/HRTMR_101.png (deflated 8%)',
#  '  adding: hr_tumor_imgs/HRTMR_104.png (deflated 4%)',
#  '  adding: hr_tumor_imgs/HRTMR_61.png (deflated 14%)',
#  '  adding: hr_tumor_imgs/HRTMR_8.png (deflated 13%)',
#  '  adding: hr_tumor_imgs/HRTMR_23.png (deflated 15%)',
#  '  adding: hr_tumor_imgs/HRTMR_13.png (deflated 10%)',
#  '  adding: hr_tumor_imgs/HRTMR_138.png (deflated 13%)',
#  '  adding: hr_tumor_imgs/HRTMR_19.png (deflated 5%)',
#  '  adding: hr_tumor_imgs/HRTMR_121.png (deflated 13%)',
#  '  adding: hr_tumor_imgs/HRTMR_84.png (deflated 13%)',
#  '  adding: hr_tumor_imgs/HRTMR_18.png (deflated 14%)',
#  '  adding: hr_tumor_imgs/HRTMR_67.png (deflated 12%)',
#  '  adding: hr_tumor_imgs/HRTMR_26.png (deflated 4%)',
#  '  adding: hr_tumor_imgs/HRTMR_108.png (deflated 6%)',
#  '  adding: hr_tumor_imgs/HRTMR_21.png (deflated 6%)',
#  '  adding: hr_tumor_imgs/HRTMR_75.png (deflated 14%)',
#  '  adding: hr_tumor_imgs/HRTMR_89.png (deflated 8%)',
#  '  adding: hr_tumor_imgs/HRTMR_162.png (deflated 11%)',
#  '  adding: hr_tumor_imgs/HRTMR_140.png (deflated 31%)',
#  '  adding: hr_tumor_imgs/HRTMR_119.png (deflated 7%)',
#  '  adding: hr_tumor_imgs/HRTMR_32.png (deflated 10%)',
#  '  adding: hr_tumor_imgs/HRTMR_184.png (deflated 4%)',
#  '  adding: hr_tumor_imgs/HRTMR_190.png (deflated 14%)',
#  '  adding: hr_tumor_imgs/HRTMR_182.png (deflated 13%)',
#  '  adding: hr_tumor_imgs/HRTMR_178.png (deflated 14%)',
#  '  adding: hr_tumor_imgs/HRTMR_14.png (deflated 15%)',
#  '  adding: hr_tumor_imgs/HRTMR_151.png (deflated 11%)',
#  '  adding: hr_tumor_imgs/HRTMR_72.png (deflated 11%)',
#  '  adding: hr_tumor_imgs/HRTMR_27.png (deflated 7%)',
#  '  adding: hr_tumor_imgs/HRTMR_192.png (deflated 6%)',
#  '  adding: hr_tumor_imgs/HRTMR_63.png (deflated 19%)',
#  '  adding: hr_tumor_imgs/HRTMR_53.png (deflated 8%)',
#  '  adding: hr_tumor_imgs/HRTMR_127.png (deflated 12%)',
#  '  adding: hr_tumor_imgs/HRTMR_28.png (deflated 6%)',
#  '  adding: hr_tumor_imgs/HRTMR_197.png (deflated 25%)',
#  '  adding: hr_tumor_imgs/HRTMR_17.png (deflated 13%)',
#  '  adding: hr_tumor_imgs/HRTMR_90.png (deflated 6%)',
#  '  adding: hr_tumor_imgs/HRTMR_187.png (deflated 10%)',
#  '  adding: hr_tumor_imgs/HRTMR_110.png (deflated 14%)',
#  '  adding: hr_tumor_imgs/HRTMR_158.png (deflated 13%)',
#  '  adding: hr_tumor_imgs/HRTMR_99.png (deflated 7%)',
#  '  adding: hr_tumor_imgs/HRTMR_175.png (deflated 12%)',
#  '  adding: hr_tumor_imgs/HRTMR_159.png (deflated 10%)',
#  '  adding: hr_tumor_imgs/HRTMR_73.png (deflated 7%)',
#  '  adding: hr_tumor_imgs/HRTMR_137.png (deflated 14%)',
#  '  adding: hr_tumor_imgs/HRTMR_109.png (deflated 14%)',
#  '  adding: hr_tumor_imgs/HRTMR_130.png (deflated 5%)',
#  '  adding: hr_tumor_imgs/HRTMR_11.png (deflated 10%)',
#  '  adding: hr_tumor_imgs/HRTMR_7.png (deflated 12%)',
#  '  adding: hr_tumor_imgs/HRTMR_95.png (deflated 12%)',
#  '  adding: hr_tumor_imgs/HRTMR_92.png (deflated 9%)',
#  '  adding: hr_tumor_imgs/HRTMR_166.png (deflated 5%)',
#  '  adding: hr_tumor_imgs/HRTMR_98.png (deflated 16%)',
#  '  adding: hr_tumor_imgs/HRTMR_146.png (deflated 8%)',
#  '  adding: hr_tumor_imgs/HRTMR_30.png (deflated 6%)',
#  '  adding: hr_tumor_imgs/HRTMR_36.png (deflated 10%)',
#  '  adding: hr_tumor_imgs/HRTMR_167.png (deflated 5%)',
#  '  adding: hr_tumor_imgs/HRTMR_170.png (deflated 6%)',
#  '  adding: hr_tumor_imgs/HRTMR_183.png (deflated 26%)',
#  '  adding: hr_tumor_imgs/HRTMR_125.png (deflated 10%)',
#  '  adding: hr_tumor_imgs/HRTMR_94.png (deflated 31%)',
#  '  adding: hr_tumor_imgs/HRTMR_196.png (deflated 8%)',
#  '  adding: hr_tumor_imgs/HRTMR_113.png (deflated 27%)']
